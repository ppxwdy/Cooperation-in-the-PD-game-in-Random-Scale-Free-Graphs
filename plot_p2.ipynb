# %%
import pandas as pd
import matplotlib.pyplot as plt

k2 = pd.read_csv('part2_k2.csv')
k3 = pd.read_csv('part2_k3.csv')

# %%
k2.shape[0]
# Out:
# 10001

# %%
k3.head()
# Out:
#        1.0      1.1  1.2000000000000002  1.3000000000000003  \
# 0  0.29980  0.29980             0.29980             0.29980
# 1  0.48950  0.45425             0.44625             0.44375
# 2  0.62375  0.57275             0.54950             0.54925
# 3  0.71350  0.64975             0.62925             0.62500
# 4  0.77400  0.70375             0.69275             0.69250
#
#    1.4000000000000004  1.5000000000000004  1.6000000000000005  \
# 0             0.29980             0.29980             0.29980
# 1             0.42150             0.38575             0.38775
# 2             0.51775             0.46325             0.45200
# 3             0.58975             0.51325             0.50125
# 4             0.64525             0.55700             0.54525
#
#    1.7000000000000006  1.8000000000000007  1.9000000000000008  ...  \
# 0             0.29980             0.29980             0.29980  ...
# 1             0.37450             0.37025             0.36575  ...
# 2             0.44375             0.43325             0.42775  ...
# 3             0.48725             0.48600             0.48600  ...
# 4             0.52350             0.52400             0.52575  ...
#
#    2.4000000000000012  2.5000000000000013  2.6000000000000014  \
# 0             0.29980             0.29980             0.29980
# 1             0.34025             0.33525             0.32875
# 2             0.37300             0.36150             0.35050
# 3             0.40525             0.38350             0.37575
# 4             0.42800             0.40350             0.39650
#
#    2.7000000000000015  2.8000000000000016  2.9000000000000017  \
# 0             0.29980             0.29980             0.29980
# 1             0.32325             0.32675             0.32100
# 2             0.34325             0.35250             0.35125
# 3             0.36525             0.37250             0.37300
# 4             0.38400             0.39575             0.39100
#
#    3.0000000000000018  3.100000000000002  3.200000000000002  3.300000000000002
# 0             0.29980            0.29980            0.29980            0.29980
# 1             0.32025            0.32000            0.31850            0.31800
# 2             0.33650            0.34125            0.33575            0.33325
# 3             0.35675            0.36000            0.35100            0.34525
# 4             0.36700            0.37325            0.36500            0.35825
#
# [5 rows x 24 columns]

# %%
record_k2 = dict()
record_k3 = dict()
for col in k2.columns:
    record_k2[col] = k2[col].to_list()
    record_k3[col] = k3[col].to_list()

# %%
import numpy as np
fig, ax = plt.subplots(2, 1, figsize=(10, 18), sharex='all')
t = [i for i in range(1, k2.shape[0]+1)]
bs = list(record_k2.keys())
for b in bs:
    ax[0].plot(t, record_k2[b], 'o-', markersize=0.5, lw=1, label='b is '+str(b))
    ax[1].plot(t, record_k3[b], 'o-', markersize=0.5, lw=1, label='b is '+str(b))

ax[0].set_yscale('log')
ax[1].set_yscale('log')

ax[1].legend(loc=(.05, -.4), ncol=3)
ax[0].set_ylabel('b')
ax[1].set_ylabel('b')
plt.xlim(1)
plt.xscale('log')
plt.xlabel('t')
plt.show()
